# %% [markdown]
# <a href="https://colab.research.google.com/github/nebink/Python-project/blob/main/Sales_forecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn. linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
store_sales = pd.read_csv("train.csv")
store_sales.head(10)
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10
# 5  2013-01-06      1     1     12
# 6  2013-01-07      1     1     10
# 7  2013-01-08      1     1      9
# 8  2013-01-09      1     1     12
# 9  2013-01-10      1     1      9

# %% [markdown]
# to check null values in the dataset

# %%
store_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  object
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 27.9+ MB

# %% [markdown]
# Dropping store and item columns

# %%
store_sales = store_sales.drop(['item' , 'store'], axis=1)

# %%
store_sales.head()
# Out:
#          date  sales
# 0  2013-01-01     13
# 1  2013-01-02     11
# 2  2013-01-03     14
# 3  2013-01-04     13
# 4  2013-01-05     10

# %% [markdown]
#   Converting date datatype from object to dateTime datatype

# %%
store_sales = pd.to_datetime(store_sales["date"])

# %%
store_sales.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 913000 entries, 0 to 912999
# Series name: date
# Non-Null Count   Dtype
# --------------   -----
# 913000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.0 MB

# %% [markdown]
# Converting date to a period of month Adding the number of sales for each month

# %%
monthly_sales = store_sales.groupby('date').sum().reset.index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-04c73bf130da> in <cell line: 1>()
# ----> 1 monthly_sales = store_sales.groupby('date').sum().reset.index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2074         axis = self._get_axis_number(axis)
#    2075
# -> 2076         return SeriesGroupBy(
#    2077             obj=self,
#    2078             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
#     966                 obj,
# ...
